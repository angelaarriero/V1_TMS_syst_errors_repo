# %%
import sys
import os
# Ruta absoluta a tu proyecto principal
ruta_base = "/home/aarriero/Documents/Angela_cmb/four_year/"
# Agregar al sys.path (al inicio para prioridad)
sys.path.insert(0, ruta_base)
#print(ruta_base)

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
sys.path.append(os.path.join(ruta_base, "general_documents/definitions_files"))
from A_TMS_instrument_V3 import TMS_instrument_output

from A_graficas_paperTMS import graficas_paper_TMS
# Out:
# /home/aarriero/Documents/Angela_cmb/four_year/
# Ruta completa del archivo: /home/aarriero/Documents/Angela_cmb/four_year/general_documents/data_files/input_params_simulation_V1_def.toml
# Archivo cargado correctamente
# /home/aarriero/Documents/Angela_cmb/four_year/
# /home/aarriero/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
t_sky_r = 8
t_load_r=8
###................

# %%
total_BEM_atmos_cmb,total_FEM_atmos_cmb,total_I1_BEM_atmos_cmb,total_I2_BEM_atmos_cmb,total_I1_FEM_atmos_cmb,total_I2_FEM_atmos_cmb,freq_spec,T_sky_bet_total,T_load_bet_total,Tlss_1,Tlss_2,Tlss_3,Tlss_4,Gtot,Tn_tot_sky,Tn_tot_load,Z,dev_total_system,U1_shifted,U2_shifted,U3_shifted,U4_shifted,N1_shifted,N2_shifted,N3_shifted,N4_shifted=TMS_instrument_output(t_sky_r,t_load_r)
# Out:
# -0.3575357905118142 -0.3650665694231193
# ################## Component TEMPERATURE CONTRIBUTION
# R 0.01384414741820192 1-SPOw 0.9900000000000001 T_ext_cry 300.0 SPOw 0.01
# spoW 0.01
# window 7.11171178320597
# window 0.13693852441362991
# Tirf 50.0 E 0.0023972420751407785 1-SPOirf 0.9900000000000001 Tcryo1 50.0 SPOirf 0.01 hw 0.9755957096959317
# filter 0.6311715081803702
# filter 0.022856224603783094
# Tfhs 5.0 Wl 0.025160021119330106 hw 0.9755957096959317 hirf 0.9875279676725761
# feedhorn sky 0.13057692942861246
# feedhorn sky 0.0024646206240642263
# Tomts 5.0 Ql 0.07982581492037763 hw 0.9755957096959317 hfhs 0.9742367557262155
# omt sky out1 0.4252379107932325
# omt sky out1 0.00273880283006767
# hybrid sky out2 0.14728508639812546
# hybrid sky out2 0.0038094096479544476
# ################################
# sky_tot_gain 8.445983218006312
# sky_tot_gain*skybeta 6.373030194538441
# ################################
# ...

# %%
graficas_paper_TMS(total_BEM_atmos_cmb,total_I1_BEM_atmos_cmb,total_I2_BEM_atmos_cmb,freq_spec,T_sky_bet_total,T_load_bet_total,Tlss_1,Tlss_2,Tlss_3,Tlss_4,Gtot,Tn_tot_sky,Tn_tot_load)
# Out:
# 0

# %%
"""""
loaded_data1 = np.load('/home/aarriero/Documents/Angela_cmb/four_year/cap2_TOD_TMS/plots_paper/DS_omt_simulated.npz')
loaded_data2 = np.load('/home/aarriero/Documents/Angela_cmb/four_year/cap2_TOD_TMS/plots_paper/DS_omt_measured_R.npz')
loaded_data3 = np.load('/home/aarriero/Documents/Angela_cmb/four_year/cap2_TOD_TMS/plots_paper/DS_omt_measured_R_il_0.1.npz')
loaded_data4 = np.load('/home/aarriero/Documents/Angela_cmb/four_year/cap2_TOD_TMS/plots_paper/DS_omt_measured_R_il_0.1_10k.npz')
loaded_data5 = np.load('/home/aarriero/Documents/Angela_cmb/four_year/cap2_TOD_TMS/plots_paper/DS_omt_measured_R_il_0.35_10k.npz')


FEM1 = loaded_data1['FEM']
BEM1 = loaded_data1['BEM']
Freq = loaded_data1['freq']
FEM2 = loaded_data2['FEM']
BEM2 = loaded_data2['BEM']
FEM3 = loaded_data3['FEM']
BEM3 = loaded_data3['BEM']
FEM4 = loaded_data4['FEM']
BEM4 = loaded_data4['BEM']
BEM5 = loaded_data5['BEM']

#plt.figure()
#plt.plot(Freq,FEM1)
#plt.plot(Freq,FEM2)
#plt.plot(Freq,FEM3,color='r')

plt.figure()
#plt.plot(Freq,BEM1)
plt.plot(Freq,BEM2,color='g',label='0.35')## 0.35
plt.plot(Freq,BEM3,color='r',label='0.1 5k')## 0.1 5k
plt.plot(Freq,BEM4,color='k',label='0.1 10k')## 0.1 10k
plt.plot(Freq,BEM4,color='y',label='0.35 10k')## 0.1 10k
plt.legend()
"""""
