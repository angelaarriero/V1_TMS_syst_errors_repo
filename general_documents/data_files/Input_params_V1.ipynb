# %%
import toml
file=open("input_params_simulation_V1_def.toml","w")
data_dict={
    "Sky": { ### sky temp monochromatic [K]
        "Temperature": 8,
        "n":1000,
    },
    "4KCL": { ### Load temp monochromatic [K] and RL [dB]
        "Temperature": 8,
        "RL": -40,
    },
    "Window": { ### Window physicall temp [K] and RL-IL [dB]
        "Temperature": 300,
        "RL": -20, #-20
        "IL": -0.01 , 
    },
    "IRfilter": { ### IR filter physicall temp [K] and RL-IL [dB]
        "Temperature": 50,
        "RL": -40, #-25
        "IL":-0.01 ,
    },
    "FeedHornSky": { ### Sky feedhorn physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -30,
        "IL":-0.05,
    },
   "OMTsky": { ### sky OMT physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -25,
        "IL":-0.1,
    },
    "FeedHornload": { ### Load feedhorn physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -30,
        "IL":-0.05,
    },
    "OMTload": {  ### load OMT physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -25,
        "IL":-0.1,
    },
    "HybridX": {  ### sky Hybrid physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -25,
        "IL":-0.1,
    },
    "HybridY": { ### load Hybrid physicall temp [K] and RL-IL [dB]
        "Temperature": 5,
        "RL": -25,
        "IL":-0.1,
    },
    "LNA1": { ### LNA1 noise temp [K] and RL[dB] and Gain [dB]
        "Tnoise":  3.8,
        "RL": -15,
        "Gain":28,
    },
    "LNA2": { ### LNA2 noise temp [K] and RL[dB] and Gain [dB]
        "Tnoise": 3.8,
        "RL": -15,
        "Gain":28,
    },
    "LNA3": { ### LNA3 noise temp [K] and RL[dB] and Gain [dB]
        "Tnoise":  3.8,
        "RL": -15,
        "Gain":28,
    },
    "LNA4": { ### LNA4 noise temp [K] and RL[dB] and Gain [dB]
        "Tnoise":  3.8,
        "RL": -15,
        "Gain":28,
    },
    "SPO": { ### Spillover [dB] for window, IRfilter and Load
        "Window": -20,#0.00630957344480193 -20
        "IRfilter": -20,#0.001995262314968879 -20
        "4KCL": -48.5, #-48.5
    },
    "Environment": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "Tenv1": 50.1,
        "Tenv2": 5.1,## 5.1
        "Troom": 300,
        "T_ext_cry": 300,
        "T_BEM_filter": 300,
        "T_after_filt_BEM": 300,
        "T_after_ampl_DC": 300,
        "T_FPGA": 300, 
        "Tcryo1": 50,
        "Tcryo2": 5,
        
    },
    "BEM_amp": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "RL": -15,
        "Fnoise":4,
        "Gain":28,
        
    },
    "BEM_filter": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "RL": -25,
        "IL":-2,
        
    },
    "DC_amp": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "RL": -15,
        "Fnoise":3,
        "Gain":17,
        
    },
    "DC_filter": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "RL": -25,
        "IL":-2,
        
    },
    "Mixer": { ### Environment and cryogenicall temperatures (Troom, 1st stage, 2nd stage)
        "Fnoise": 6.9,
        "Lmixer":-6.9,
        "LO":0,
        "T_mixer":300,
        
    },
}
toml.dump(data_dict,file)
file.close()
